# %% [markdown]
# # welcome back

# %%
import pandas as pd

# %%
details=pd.read_csv('details.csv')

# %%
details
# Out:
#             Timestamp                 Email Address                     Name  \
# 0   8/9/2022 22:43:47      rinujoseph2003@gmail.com              Rinu Joseph
# 1   8/9/2022 22:47:35      dakshinapkumar@gmail.com         Dakshina P Kumar
# 2   8/9/2022 22:48:09             s892815@gmail.com                 Sourav S
# 3   8/9/2022 22:50:18         antonyalka0@gmail.com              Alka Antony
# 4   8/9/2022 22:51:09  ananthakrishnan829@gmail.com        Anantha Krishnan
# 5   8/9/2022 23:02:34     vimalkrishnarao@gmail.com     M Vimal Krishna Rao
# 6   8/9/2022 23:05:09       aakashbaiju18@gmail.com                   Aakash
# 7   8/9/2022 23:06:39          anjuelsa15@gmail.com            Anju Varghese
# 8   8/9/2022 23:08:17    jayalakshmiv2003@gmail.com            Jayalakshmi V
# 9   8/9/2022 23:08:39   mirsamuhammed2003@gmail.com          Mirza Muhammed
# 10  8/9/2022 23:08:39    shahmamuhammed56@gmail.com                   Shahma
# ...

# %%
contact=[]

# %%
type(list(details.iterrows())[1][1]['Name'])
# Out:
# str

# %%
for i in list(details.iterrows()):
    if i not in contact:
        contact.append([i[1]['Name'],f"+91 {i[1]['Contact Number']}"])

# %%
import pywhatkit
for i in contact:
    pywhatkit.sendwhatmsg_instantly(i[1],f"Hey {i[0]} I'm Arjun, please join the group to know more about the Python Bootcamp for beginners  ",10)
# Out:
# [['Rinu Joseph', '+91 8590890153'],
#  ['Dakshina P Kumar', '+91 7902802856'],
#  ['Sourav S', '+91 9188342497'],
#  ['Alka Antony', '+91 7736860497'],
#  ['Anantha Krishnan ', '+91 9778186595'],
#  ['M Vimal Krishna Rao ', '+91 9995650193'],
#  ['Aakash', '+91 8304825202'],
#  ['Anju Varghese', '+91 9656051254'],
#  ['Jayalakshmi V', '+91 8848227168'],
#  ['Mirza Muhammed ', '+91 9497599162'],
#  ['Shahma', '+91 7559848938'],
#  ['Muhammed Abnas', '+91 9947657790'],
#  ['Diya Nair D ', '+91 9605619737'],
#  ['Muhammad Yasin Shereef ', '+91 8137025459'],
#  ['Adhwaith A M', '+91 9947534844'],
#  ['Devi Krishna R', '+91 8921232220'],
#  ['Diana Liz Kuriakose ', '+91 9446710040'],
#  ['Varsha A Nair', '+91 7034426013'],
#  ['Peter Mathai Samuel ', '+91 8547115003'],
#  ['Ajmal J S ', '+91 8593830977'],
#  ['Akash G Nair ', '+91 7994831729'],
#  ['Abin T Sunil', '+91 8848651035'],
#  ['Aswin Satheesh ', '+91 8138963028'],
#  ['Dev Nand D', '+91 7736915819']]
