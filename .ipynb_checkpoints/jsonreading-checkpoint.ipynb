# %%
import json

# %%
f=open('converted.json','r')

# %%
p=json.load(f)

# %%
p
# Out:
# {'1': {'ID': '1',
#   'Disease': 'Allergy',
#   'Symtoms': 'nasal congestion,\nitchy and watery eyes,\nsneezing,\nstuffy or runny nose,\nscratchy or sore throat,\nthroat clearing,\ncough from postnasal drip.'},
#  '2': {'ID': '2',
#   'Disease': 'anemia',
#   'Symtoms': 'Feel tired or lightheaded (sometimes with fainting)\nWeakness\nFatigue easily\nHave decreased energy\nAppear pale\nDevelop palpitations or rapid heart rate\nExperience shortness of breath'},
#  '3': {'ID': '3',
#   'Disease': 'cold/flu',
#   'Symtoms': 'Headaches, body aches, fever, and flu-like symptoms\nNasal congestion, runny nose, and sneezing\nCough\nSore throat'},
#  '4': {'ID': '4',
#   'Disease': 'asthama',
#   'Symtoms': 'shortness of breath, chest pain,cough'},
#  '5': {'ID': '5',
#   'Disease': 'alzheimers',
#   'Symtoms': 'loss of orientation (to person, place, or time),\nagitation,\nirritability,\nquarrelsomeness, and\na diminishing ability to care for him- or herself and to dress appropriately.'},
# ...

# %%
for i in p.items():
    print(i[1]['ID']+'       '+str(i[1]['Disease']))
# Out:
# 1       Allergy
# 2       anemia
# 3       cold/flu
# 4       asthama
# 5       alzheimers
# 6       pregnancy
# 7       hyperthyroid
# 8       hypothyroid
# 9       diabetes
# 10       HIV AIDS
# 11       high blood pressure
# 12       Rheumatoid Arthritis
# 13       hepatitis B
# 14       Dengue
# 15       Malaria
# 16       Chicken Pox
# 17       jaundice
# 18       Diarrhea
# 19       cataract
# 20       pneumonia
# 21       Urinary Retention
# 22       Insomnia
# 23       Sinus Infection
# 24       hepatitis c
# 25       mumps
# 26       measles
# 27       botulism
# 28       mad cow disease
# 29       meningetis
# 30       indigestion
# 31       constipation
# 32       appendicitis
# 33       Anxiety Disorder
# 34       crohn's disease
# 35       narcolepsy
# 36       cystinuria
# 37       prostatitis
# 38       Angina
# 39       west nile virus
# 40       Staph Infection
# 41       Macular Degeneration(Age-Related Type)
# 42       Retinal detachment
# 43       Glaucoma
# ...

# %%
for i in p.items():
    print(i[1]['Disease'])
# Out:
# Allergy
# anemia
# cold/flu
# asthama
# alzheimers
# pregnancy
# hyperthyroid
# hypothyroid
# diabetes
# HIV AIDS
# high blood pressure
# Rheumatoid Arthritis
# hepatitis B
# Dengue
# Malaria
# Chicken Pox
# jaundice
# Diarrhea
# cataract
# pneumonia
# Urinary Retention
# Insomnia
# Sinus Infection
# hepatitis c
# mumps
# measles
# botulism
# mad cow disease
# meningetis
# indigestion
# constipation
# appendicitis
# Anxiety Disorder
# crohn's disease
# narcolepsy
# cystinuria
# prostatitis
# Angina
# west nile virus
# Staph Infection
# Macular Degeneration(Age-Related Type)
# Retinal detachment
# Glaucoma
# hysterectomy
# yeast infection
# anorexia
# chronic obstructive pulmonary disease 5
# emphysema
# boils
# keloid scar
# rosacea
# shingles(herpes zoster)
# dandruff
# acne
# common wart
# Scleroderma
# Lichen planus
# Dementia
# hives
# bulimia nervosa
# erectile dysfunction
# Enlarged Prostate Gland
# Dysthymia (Persistent Depressive Disorder)
#  panic attack
# bipolar disorder
# ...
