# %%
import chart_studio as py
import pandas as pd
import plotly.graph_objs as go
import json

# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
kerala_district=json.load(open("kerala_dist.geojson",'r'))

# %%
kerala_district["features"][1]
# Out:
# {'type': 'Feature',
#  'properties': {'DISTRICT': 'Ernakulam',
#   'ST_NM': 'Kerala',
#   'ST_CEN_CD': 32,
#   'DT_CEN_CD': 8,
#   'censuscode': 595,
#   'orig_ogc_f': 173},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[76.68924459922391, 10.26720683638176],
#     [76.68724217242732, 10.261704063987649],
#     [76.68322664562854, 10.256786801027589],
#     [76.68064668772084, 10.251687763130253],
#     [76.68118324017179, 10.24026850145209],
#     [76.67904284716137, 10.22822670422531],
#     [76.67580560003809, 10.217395220488028],
#     [76.67376333703227, 10.213901340372091],
#     [76.66111955176574, 10.198742447531615],
#     [76.65826200408236, 10.19576970466825],
#     [76.6521601209119, 10.191431489679085],
#     [76.6442252154378, 10.166212277505926],
#     [76.64339380228238, 10.161453738183452],
#     [76.64910790170656, 10.155771465415627],
#     [76.65830288756248, 10.14076328881593],
#     [76.66160392806506, 10.139430954704043],
# ...

# %%
from urllib.request import urlopen
with urlopen("https://api.covid19india.org/state_district_wise.json") as f:
  data = json.load(f)

# %%
data1=f"{data}"

# %%
data2=json.dumps(data)

# %%
data2
# Out:
# '{"State Unassigned": {"districtData": {"Unassigned": {"notes": "", "active": 0, "confirmed": 0, "deceased": 0, "recovered": 0, "delta": {"confirmed": 0, "deceased": 0, "recovered": 0}}}, "statecode": "UN"}, "Andaman and Nicobar Islands": {"districtData": {"Nicobars": {"notes": "District-wise numbers are out-dated as cumulative counts for each district are not reported in bulletin", "active": 0, "confirmed": 0, "deceased": 0, "recovered": 0, "delta": {"confirmed": 0, "deceased": 0, "recovered": 0}}, "North and Middle Andaman": {"notes": "District-wise numbers are out-dated as cumulative counts for each district are not reported in bulletin", "active": 0, "confirmed": 1, "deceased": 0, "recovered": 1, "delta": {"confirmed": 0, "deceased": 0, "recovered": 0}}, "South Andaman": {"notes": "District-wise numbers are out-dated as cumulative counts for each district are not reported in bulletin", "active": 19, "confirmed": 51, "deceased": 0, "recovered": 32, "delta": {"confirmed": 0, "decea
# ...

# %%
import shutil

# %%
import os
source = "C:\\Users\\Dell\\Desktop\\kerala_data.json"
destination ="C:\\Users\\Dell\\Documents\\Machine Learning by jose\\Datascience\\Covid19 stats\\kerala_data.json"

# %%
shutil.copyfile(source, destination)
# Out:
# 'C:\\Users\\Dell\\Documents\\Machine Learning by jose\\Datascience\\Covid19 stats\\kerala_data.json'

# %%
df=pd.read_json(r"C:\\Users\\Dell\\Documents\\Machine Learning by jose\\Datascience\\Covid19 stats\\kerala_data.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-8ae1cff17d2c> in <module>
# ----> 1 df=pd.read_json(r'C:\\Users\\Dell\\Documents\\Machine Learning by jose\\Datascience\\Covid19 stats\\kerala_data.json')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
# ...
